# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

# %%
from matplotlib import pyplot as plt

years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.5]

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

plt.ylabel('Млрд $')
plt.xlabel('Года')
plt.show()

# %%
movies = ["Энни Холл", "Бен-Гур", "Касбаланка", "Ганди          ", "Вестсайдская история"]
num_oscar = [5, 11, 3, 8, 10]

plt.title("Мои любимые фильмы")
plt.ylabel("Колличество наград")

plt.bar(range(len(movies)), num_oscar)

plt.xticks(range(len(movies)), movies)
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

histogram = Counter(min(grade // 10 * 10, 90) for grade in grades)

plt.bar([x + 5 for x in histogram.keys()],
        histogram.values(),  # missing comma here
        10,
        edgecolor = (0, 0, 0))

plt.axis([-5, 105, 0, 5])

plt.xticks([10 * i for i in range(11)],)
plt.xlabel("Дециль")
plt.ylabel("Число сдудентов")
plt.title("Распределение оценок на экзамене №1")
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]

total_error= [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance, 'g-', label = 'Дисперсия')
plt.plot(xs, bias_squared, 'r-', label = 'Смещение^2')
plt.plot(xs, total_error, 'b:', label = 'Суммарная ошибка')
plt.legend(loc=9)
plt.xlabel("Сложность модели")
plt.ylabel("Компромисс между смещением и дисперсией")
plt.show()

# %%
# from collections import Counter
# import matplotlib.pyplot as plt
